# %%
import pandas as pd

# %%
# Read in the excel
read_file = pd.read_excel (".\Resources\county-to-county-2015-2019-current-residence-sort.xlsx")
# Write the dataframe object into csv file without the header
read_file.to_csv (".\Resources\cleaned-county-to-county-2015-2019-current-residence-sort.csv", index = None, header=False)
# Read csv file and convert into a dataframe object
current_residence_df = pd.DataFrame(pd.read_csv(".\Resources\cleaned-county-to-county-2015-2019-current-residence-sort.csv"))
# View the dataframe
current_residence_df.head()
# Out:
#   Current Residence State Code  Current Residence FIPS County Code  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          001                                 1.0
# 3                          001                                 1.0
# 4                          001                                 1.0
#
#   Residence 1 Year Ago State/U.S. Island Area/Foreign Region Code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                001
# 3                                                001
# 4                                                001
#
#    Residence 1 Year Ago FIPS County Code State of Current Residence  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    3.0                    Alabama
# 3                                    5.0                    Alabama
# 4                                    7.0                    Alabama
#
#   County of Current Residence County of Current Residence.1 Unnamed: 7  \
# 0                         NaN    Population 1 Year and Over        NaN
# 1                         NaN                      Estimate        MOE
# 2              Autauga County                         54699        172
# 3              Autauga County                         54699        172
# 4              Autauga County                         54699        172
#
#   Unnamed: 8 Unnamed: 9  ...                Unnamed: 28 Unnamed: 29  \
# 0  Nonmovers        NaN  ...  Movers within Same County         NaN
# 1   Estimate        MOE  ...                   Estimate         MOE
# 2      48066        987  ...                      13004        1466
# 3      48066        987  ...                       2325         523
# 4      48066        987  ...                        784         352
#
#                               Unnamed: 30 Unnamed: 31  \
# 0  Movers to Different County, Same State         NaN
# 1                                Estimate         MOE
# 2                                    3133         598
# 3                                    1210         329
# 4                                    1184         408
#
#                  Unnamed: 32 Unnamed: 33            Unnamed: 34 Unnamed: 35  \
# 0  Movers to Different State         NaN  Movers to Puerto Rico         NaN
# 1                   Estimate         MOE               Estimate         MOE
# 2                       5592         827                    NaN         NaN
# 3                        325         160                    NaN         NaN
# 4                        132          88                    NaN         NaN
#
#   Movers in County-to-County Flow Unnamed: 37
# 0                             NaN         NaN
# 1                        Estimate         MOE
# 2                              25          26
# 3                               4           8
# 4                              10          16
#
# [5 rows x 38 columns]

# %%
# View list of columns
list(current_residence_df.columns.values)
# Out:
# ['Current Residence State Code',
#  'Current Residence FIPS County Code',
#  'Residence 1 Year Ago State/U.S. Island Area/Foreign Region Code',
#  'Residence 1 Year Ago FIPS County Code',
#  'State of Current Residence',
#  'County of Current Residence',
#  'County of Current Residence.1',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'State/U.S. Island Area/Foreign Region of Residence 1 Year Ago',
#  'County of Residence 1 Year Ago',
#  'County of Residence 1 Year Ago.1',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Movers in County-to-County Flow',
#  'Unnamed: 37']

# %%
#Rename columns and replace spaces with underscore
current_residence_df.rename(columns = {"Current Residence State Code":"Current_Residence_State_Code",
                            "Current Residence FIPS County Code":"Current_Residence_FIPS_County_Code",
                            "Residence 1 Year Ago State/U.S. Island Area/Foreign Region Code":"Previous_Residence_State/U.S._Island Area/Foreign_Region_Code",
                            "Residence 1 Year Ago FIPS County Code":"Previous_Residence_FIPS_County_Code",
                            "State of Current Residence":"Current_Residence_State",
                            "County of Current Residence":"Current_Residence_County",
                            "County of Current Residence.1":"Current_Residence_County_Population_1_Year_and_Over",
                            "Unnamed: 7":"Current_Residence_County_Population_1_Year_and_Over_MOE",
                            "Unnamed: 8":"Current_Residence_County_Nonmovers",
                            "Unnamed: 9":"Current_Residence_County_Nonmovers_MOE",
                            "Unnamed: 10":"Current_Residence_Movers_within_United_States",
                            "Unnamed: 11":"Current_Residence_Movers_within_United_States_1",
                            "Unnamed: 12":"Current_Residence_Movers_within_Same_County",
                            "Unnamed: 13":"Current_Residence_Movers_within_Same_County_MOE",
                            "Unnamed: 14":"Current_Residence_Movers_from_Different_County_Same_State",
                            "Unnamed: 15":"Current_Residence_Movers_from_Different_County_Same_State_MOE",
                            "Unnamed: 16":"Current_Residence_Movers_from_Different_State",
                            "Unnamed: 17":"Current_Residence_Movers_from_Different_State_MOE",
                            "Unnamed: 18":"Current_Residence_Movers_from_Abroad",
                            "Unnamed: 19":"Current_Residence_Movers_from_Abroad_MOE",
                            "State/U.S. Island Area/Foreign Region of Residence 1 Year Ago":"Previous_Residence_State/U.S._Island_Area/Foreign_Region",
                            "County of Residence 1 Year Ago":"Previous_Residence_County",
                            "County of Residence 1 Year Ago.1":"Previous_Residence_County_Population_1_Year_and_Over",
                            "Unnamed: 23":"Previous_Residence_County_Population_1_Year_and_Over_MOE",
                            "Unnamed: 24":"Previous_Residence_County_Nonmovers",
                            "Unnamed: 25":"Previous_Residence_County_Nonmovers_MOE",
                            "Unnamed: 26":"Previous_Residence_Movers_within_United_States_or_Puerto_Rico",
                            "Unnamed: 27":"Previous_Residence_Movers_within_United_States_or_Puerto_Rico_MOE",
                            "Unnamed: 28":"Previous_Residence_Movers_within_Same_County",
                            "Unnamed: 29":"Previous_Residence_Movers_within_Same_County_MOE",
                            "Unnamed: 30":"Previous_Residence_Movers_within_Different_County_Same_State",
                            "Unnamed: 31":"Previous_Residence_Movers_within_Different_County_Same_State_MOE",
                            "Unnamed: 32":"Previous_Residence_Movers_within_Different_State",
                            "Unnamed: 33":"Previous_Residence_Movers_within_Different_State_MOE",
                            "Unnamed: 34":"Previous_Residence_Movers_to_Puerto_Rico",
                            "Unnamed: 35":"Previous_Residence_Movers_to_Puerto_Rico_MOE",
                            "Movers in County-to-County Flow":"Movers_in_County_to_County_Flow",
                            "Unnamed: 37":"Movers_in_County_to_County_Flow_MOE"}
                           , inplace = True)
current_residence_df.head()
# Out:
#   Current_Residence_State_Code  Current_Residence_FIPS_County_Code  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          001                                 1.0
# 3                          001                                 1.0
# 4                          001                                 1.0
#
#   Previous_Residence_State/U.S._Island Area/Foreign_Region_Code  \
# 0                                                NaN
# 1                                                NaN
# 2                                                001
# 3                                                001
# 4                                                001
#
#    Previous_Residence_FIPS_County_Code Current_Residence_State  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  3.0                 Alabama
# 3                                  5.0                 Alabama
# 4                                  7.0                 Alabama
#
#   Current_Residence_County  \
# 0                      NaN
# 1                      NaN
# 2           Autauga County
# 3           Autauga County
# 4           Autauga County
#
#   Current_Residence_County_Population_1_Year_and_Over  \
# 0                         Population 1 Year and Over
# 1                                           Estimate
# 2                                              54699
# 3                                              54699
# 4                                              54699
#
#   Current_Residence_County_Population_1_Year_and_Over_MOE  \
# 0                                                NaN
# 1                                                MOE
# 2                                                172
# 3                                                172
# 4                                                172
#
#   Current_Residence_County_Nonmovers Current_Residence_County_Nonmovers_MOE  \
# 0                          Nonmovers                                    NaN
# 1                           Estimate                                    MOE
# 2                              48066                                    987
# 3                              48066                                    987
# 4                              48066                                    987
#
#    ... Previous_Residence_Movers_within_Same_County  \
# 0  ...                    Movers within Same County
# 1  ...                                     Estimate
# 2  ...                                        13004
# 3  ...                                         2325
# 4  ...                                          784
#
#   Previous_Residence_Movers_within_Same_County_MOE  \
# 0                                              NaN
# 1                                              MOE
# 2                                             1466
# 3                                              523
# 4                                              352
#
#   Previous_Residence_Movers_within_Different_County_Same_State  \
# 0             Movers to Different County, Same State
# 1                                           Estimate
# 2                                               3133
# 3                                               1210
# 4                                               1184
#
#   Previous_Residence_Movers_within_Different_County_Same_State_MOE  \
# 0                                                NaN
# 1                                                MOE
# 2                                                598
# 3                                                329
# 4                                                408
#
#   Previous_Residence_Movers_within_Different_State  \
# 0                        Movers to Different State
# 1                                         Estimate
# 2                                             5592
# 3                                              325
# 4                                              132
#
#   Previous_Residence_Movers_within_Different_State_MOE  \
# 0                                                NaN
# 1                                                MOE
# 2                                                827
# 3                                                160
# 4                                                 88
#
#   Previous_Residence_Movers_to_Puerto_Rico  \
# 0                    Movers to Puerto Rico
# 1                                 Estimate
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Previous_Residence_Movers_to_Puerto_Rico_MOE  \
# 0                                          NaN
# 1                                          MOE
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Movers_in_County_to_County_Flow Movers_in_County_to_County_Flow_MOE
# 0                             NaN                                 NaN
# 1                        Estimate                                 MOE
# 2                              25                                  26
# 3                               4                                   8
# 4                              10                                  16
#
# [5 rows x 38 columns]

# %%
# Dropping first two rows and re-indexing
current_residence_df = current_residence_df.drop([0,1], axis=0, inplace=False)
current_residence_df = current_residence_df.reset_index(drop=True)
current_residence_df.head()
# Out:
#   Current_Residence_State_Code  Current_Residence_FIPS_County_Code  \
# 0                          001                                 1.0
# 1                          001                                 1.0
# 2                          001                                 1.0
# 3                          001                                 1.0
# 4                          001                                 1.0
#
#   Previous_Residence_State/U.S._Island Area/Foreign_Region_Code  \
# 0                                                001
# 1                                                001
# 2                                                001
# 3                                                001
# 4                                                001
#
#    Previous_Residence_FIPS_County_Code Current_Residence_State  \
# 0                                  3.0                 Alabama
# 1                                  5.0                 Alabama
# 2                                  7.0                 Alabama
# 3                                  9.0                 Alabama
# 4                                 15.0                 Alabama
#
#   Current_Residence_County  \
# 0           Autauga County
# 1           Autauga County
# 2           Autauga County
# 3           Autauga County
# 4           Autauga County
#
#   Current_Residence_County_Population_1_Year_and_Over  \
# 0                                              54699
# 1                                              54699
# 2                                              54699
# 3                                              54699
# 4                                              54699
#
#   Current_Residence_County_Population_1_Year_and_Over_MOE  \
# 0                                                172
# 1                                                172
# 2                                                172
# 3                                                172
# 4                                                172
#
#   Current_Residence_County_Nonmovers Current_Residence_County_Nonmovers_MOE  \
# 0                              48066                                    987
# 1                              48066                                    987
# 2                              48066                                    987
# 3                              48066                                    987
# 4                              48066                                    987
#
#    ... Previous_Residence_Movers_within_Same_County  \
# 0  ...                                        13004
# 1  ...                                         2325
# 2  ...                                          784
# 3  ...                                         2024
# 4  ...                                        11467
#
#   Previous_Residence_Movers_within_Same_County_MOE  \
# 0                                             1466
# 1                                              523
# 2                                              352
# 3                                              425
# 4                                             1413
#
#   Previous_Residence_Movers_within_Different_County_Same_State  \
# 0                                               3133
# 1                                               1210
# 2                                               1184
# 3                                               1818
# 4                                               4162
#
#   Previous_Residence_Movers_within_Different_County_Same_State_MOE  \
# 0                                                598
# 1                                                329
# 2                                                408
# 3                                                436
# 4                                                565
#
#   Previous_Residence_Movers_within_Different_State  \
# 0                                             5592
# 1                                              325
# 2                                              132
# 3                                              583
# 4                                             2459
#
#   Previous_Residence_Movers_within_Different_State_MOE  \
# 0                                                827
# 1                                                160
# 2                                                 88
# 3                                                209
# 4                                                577
#
#   Previous_Residence_Movers_to_Puerto_Rico  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                       67
#
#   Previous_Residence_Movers_to_Puerto_Rico_MOE  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                           78
#
#   Movers_in_County_to_County_Flow Movers_in_County_to_County_Flow_MOE
# 0                              25                                  26
# 1                               4                                   8
# 2                              10                                  16
# 3                               3                                   6
# 4                               2                                   4
#
# [5 rows x 38 columns]

# %%
# View list of columns after renaming
list(current_residence_df.columns.values)
# Out:
# ['Current_Residence_State_Code',
#  'Current_Residence_FIPS_County_Code',
#  'Previous_Residence_State/U.S._Island Area/Foreign_Region_Code',
#  'Previous_Residence_FIPS_County_Code',
#  'Current_Residence_State',
#  'Current_Residence_County',
#  'Current_Residence_County_Population_1_Year_and_Over',
#  'Current_Residence_County_Population_1_Year_and_Over_MOE',
#  'Current_Residence_County_Nonmovers',
#  'Current_Residence_County_Nonmovers_MOE',
#  'Current_Residence_Movers_within_United_States',
#  'Current_Residence_Movers_within_United_States_1',
#  'Current_Residence_Movers_within_Same_County',
#  'Current_Residence_Movers_within_Same_County_MOE',
#  'Current_Residence_Movers_from_Different_County_Same_State',
#  'Current_Residence_Movers_from_Different_County_Same_State_MOE',
#  'Current_Residence_Movers_from_Different_State',
#  'Current_Residence_Movers_from_Different_State_MOE',
#  'Current_Residence_Movers_from_Abroad',
#  'Current_Residence_Movers_from_Abroad_MOE',
#  'Previous_Residence_State/U.S._Island_Area/Foreign_Region',
#  'Previous_Residence_County',
#  'Previous_Residence_County_Population_1_Year_and_Over',
#  'Previous_Residence_County_Population_1_Year_and_Over_MOE',
#  'Previous_Residence_County_Nonmovers',
#  'Previous_Residence_County_Nonmovers_MOE',
#  'Previous_Residence_Movers_within_United_States_or_Puerto_Rico',
#  'Previous_Residence_Movers_within_United_States_or_Puerto_Rico_MOE',
#  'Previous_Residence_Movers_within_Same_County',
#  'Previous_Residence_Movers_within_Same_County_MOE',
#  'Previous_Residence_Movers_within_Different_County_Same_State',
#  'Previous_Residence_Movers_within_Different_County_Same_State_MOE',
#  'Previous_Residence_Movers_within_Different_State',
#  'Previous_Residence_Movers_within_Different_State_MOE',
#  'Previous_Residence_Movers_to_Puerto_Rico',
#  'Previous_Residence_Movers_to_Puerto_Rico_MOE',
#  'Movers_in_County_to_County_Flow',
#  'Movers_in_County_to_County_Flow_MOE']

# %%
#dropping non-relevant columns into a new dataframe
cleaned_cr_df=current_residence_df.drop(columns=["Current_Residence_State_Code",
                                                "Current_Residence_FIPS_County_Code",
                                                "Previous_Residence_State/U.S._Island Area/Foreign_Region_Code",
                                                "Previous_Residence_FIPS_County_Code",
                                                "Current_Residence_County_Population_1_Year_and_Over_MOE",
                                                "Current_Residence_County_Nonmovers_MOE",
                                                "Current_Residence_Movers_within_United_States_1",
                                                "Current_Residence_Movers_within_Same_County_MOE",
                                                "Current_Residence_Movers_from_Different_County_Same_State_MOE",
                                                "Current_Residence_Movers_from_Different_State_MOE",
                                                "Current_Residence_Movers_from_Abroad_MOE",
                                                "Previous_Residence_County_Population_1_Year_and_Over_MOE",
                                                "Previous_Residence_County_Nonmovers_MOE",
                                                "Previous_Residence_Movers_within_United_States_or_Puerto_Rico_MOE",
                                                "Previous_Residence_Movers_within_Same_County_MOE",
                                                "Previous_Residence_Movers_within_Different_County_Same_State_MOE",
                                                "Previous_Residence_Movers_within_Different_State_MOE",
                                                "Previous_Residence_Movers_to_Puerto_Rico_MOE",
                                                "Movers_in_County_to_County_Flow_MOE"], inplace=False)
cleaned_cr_df.head()
# Out:
#   Current_Residence_State Current_Residence_County  \
# 0                 Alabama           Autauga County
# 1                 Alabama           Autauga County
# 2                 Alabama           Autauga County
# 3                 Alabama           Autauga County
# 4                 Alabama           Autauga County
#
#   Current_Residence_County_Population_1_Year_and_Over  \
# 0                                              54699
# 1                                              54699
# 2                                              54699
# 3                                              54699
# 4                                              54699
#
#   Current_Residence_County_Nonmovers  \
# 0                              48066
# 1                              48066
# 2                              48066
# 3                              48066
# 4                              48066
#
#   Current_Residence_Movers_within_United_States  \
# 0                                          6539
# 1                                          6539
# 2                                          6539
# 3                                          6539
# 4                                          6539
#
#   Current_Residence_Movers_within_Same_County  \
# 0                                        2976
# 1                                        2976
# 2                                        2976
# 3                                        2976
# 4                                        2976
#
#   Current_Residence_Movers_from_Different_County_Same_State  \
# 0                                               2015
# 1                                               2015
# 2                                               2015
# 3                                               2015
# 4                                               2015
#
#   Current_Residence_Movers_from_Different_State  \
# 0                                          1548
# 1                                          1548
# 2                                          1548
# 3                                          1548
# 4                                          1548
#
#   Current_Residence_Movers_from_Abroad  \
# 0                                   94
# 1                                   94
# 2                                   94
# 3                                   94
# 4                                   94
#
#   Previous_Residence_State/U.S._Island_Area/Foreign_Region  \
# 0                                            Alabama
# 1                                            Alabama
# 2                                            Alabama
# 3                                            Alabama
# 4                                            Alabama
#
#   Previous_Residence_County  \
# 0            Baldwin County
# 1            Barbour County
# 2               Bibb County
# 3             Blount County
# 4            Calhoun County
#
#   Previous_Residence_County_Population_1_Year_and_Over  \
# 0                                             207884
# 1                                              25266
# 2                                              21960
# 3                                              57849
# 4                                             113102
#
#   Previous_Residence_County_Nonmovers  \
# 0                              186155
# 1                               21406
# 2                               19860
# 3                               53424
# 4                               94947
#
#   Previous_Residence_Movers_within_United_States_or_Puerto_Rico  \
# 0                                              21729
# 1                                               3860
# 2                                               2100
# 3                                               4425
# 4                                              18088
#
#   Previous_Residence_Movers_within_Same_County  \
# 0                                        13004
# 1                                         2325
# 2                                          784
# 3                                         2024
# 4                                        11467
#
#   Previous_Residence_Movers_within_Different_County_Same_State  \
# 0                                               3133
# 1                                               1210
# 2                                               1184
# 3                                               1818
# 4                                               4162
#
#   Previous_Residence_Movers_within_Different_State  \
# 0                                             5592
# 1                                              325
# 2                                              132
# 3                                              583
# 4                                             2459
#
#   Previous_Residence_Movers_to_Puerto_Rico Movers_in_County_to_County_Flow
# 0                                      NaN                              25
# 1                                      NaN                               4
# 2                                      NaN                              10
# 3                                      NaN                               3
# 4                                       67                               2

# %%
# View list of columns after dropping columns
list(cleaned_cr_df.columns.values)
# Out:
# ['Current_Residence_State',
#  'Current_Residence_County',
#  'Current_Residence_County_Population_1_Year_and_Over',
#  'Current_Residence_County_Nonmovers',
#  'Current_Residence_Movers_within_United_States',
#  'Current_Residence_Movers_within_Same_County',
#  'Current_Residence_Movers_from_Different_County_Same_State',
#  'Current_Residence_Movers_from_Different_State',
#  'Current_Residence_Movers_from_Abroad',
#  'Previous_Residence_State/U.S._Island_Area/Foreign_Region',
#  'Previous_Residence_County',
#  'Previous_Residence_County_Population_1_Year_and_Over',
#  'Previous_Residence_County_Nonmovers',
#  'Previous_Residence_Movers_within_United_States_or_Puerto_Rico',
#  'Previous_Residence_Movers_within_Same_County',
#  'Previous_Residence_Movers_within_Different_County_Same_State',
#  'Previous_Residence_Movers_within_Different_State',
#  'Previous_Residence_Movers_to_Puerto_Rico',
#  'Movers_in_County_to_County_Flow']

# %%
cleaned_cr_df.dtypes
# Out:
# Current_Residence_State                                          object
# Current_Residence_County                                         object
# Current_Residence_County_Population_1_Year_and_Over              object
# Current_Residence_County_Nonmovers                               object
# Current_Residence_Movers_within_United_States                    object
# Current_Residence_Movers_within_Same_County                      object
# Current_Residence_Movers_from_Different_County_Same_State        object
# Current_Residence_Movers_from_Different_State                    object
# Current_Residence_Movers_from_Abroad                             object
# Previous_Residence_State/U.S._Island_Area/Foreign_Region         object
# Previous_Residence_County                                        object
# Previous_Residence_County_Population_1_Year_and_Over             object
# Previous_Residence_County_Nonmovers                              object
# Previous_Residence_Movers_within_United_States_or_Puerto_Rico    object
# Previous_Residence_Movers_within_Same_County                     object
# Previous_Residence_Movers_within_Different_County_Same_State     object
# Previous_Residence_Movers_within_Different_State                 object
# Previous_Residence_Movers_to_Puerto_Rico                         object
# Movers_in_County_to_County_Flow                                  object
# dtype: object

# %%
# Add a “County and state of current residence” column 
cleaned_cr_df['Current_Residence_County_State'] = cleaned_cr_df['Current_Residence_County'] +', '+ cleaned_cr_df['Current_Residence_State']
cleaned_cr_df.head()
# Out:
#   Current_Residence_State Current_Residence_County  \
# 0                 Alabama           Autauga County
# 1                 Alabama           Autauga County
# 2                 Alabama           Autauga County
# 3                 Alabama           Autauga County
# 4                 Alabama           Autauga County
#
#   Current_Residence_County_Population_1_Year_and_Over  \
# 0                                              54699
# 1                                              54699
# 2                                              54699
# 3                                              54699
# 4                                              54699
#
#   Current_Residence_County_Nonmovers  \
# 0                              48066
# 1                              48066
# 2                              48066
# 3                              48066
# 4                              48066
#
#   Current_Residence_Movers_within_United_States  \
# 0                                          6539
# 1                                          6539
# 2                                          6539
# 3                                          6539
# 4                                          6539
#
#   Current_Residence_Movers_within_Same_County  \
# 0                                        2976
# 1                                        2976
# 2                                        2976
# 3                                        2976
# 4                                        2976
#
#   Current_Residence_Movers_from_Different_County_Same_State  \
# 0                                               2015
# 1                                               2015
# 2                                               2015
# 3                                               2015
# 4                                               2015
#
#   Current_Residence_Movers_from_Different_State  \
# 0                                          1548
# 1                                          1548
# 2                                          1548
# 3                                          1548
# 4                                          1548
#
#   Current_Residence_Movers_from_Abroad  \
# 0                                   94
# 1                                   94
# 2                                   94
# 3                                   94
# 4                                   94
#
#   Previous_Residence_State/U.S._Island_Area/Foreign_Region  \
# 0                                            Alabama
# 1                                            Alabama
# 2                                            Alabama
# 3                                            Alabama
# 4                                            Alabama
#
#   Previous_Residence_County  \
# 0            Baldwin County
# 1            Barbour County
# 2               Bibb County
# 3             Blount County
# 4            Calhoun County
#
#   Previous_Residence_County_Population_1_Year_and_Over  \
# 0                                             207884
# 1                                              25266
# 2                                              21960
# 3                                              57849
# 4                                             113102
#
#   Previous_Residence_County_Nonmovers  \
# 0                              186155
# 1                               21406
# 2                               19860
# 3                               53424
# 4                               94947
#
#   Previous_Residence_Movers_within_United_States_or_Puerto_Rico  \
# 0                                              21729
# 1                                               3860
# 2                                               2100
# 3                                               4425
# 4                                              18088
#
#   Previous_Residence_Movers_within_Same_County  \
# 0                                        13004
# 1                                         2325
# 2                                          784
# 3                                         2024
# 4                                        11467
#
#   Previous_Residence_Movers_within_Different_County_Same_State  \
# 0                                               3133
# 1                                               1210
# 2                                               1184
# 3                                               1818
# 4                                               4162
#
#   Previous_Residence_Movers_within_Different_State  \
# 0                                             5592
# 1                                              325
# 2                                              132
# 3                                              583
# 4                                             2459
#
#   Previous_Residence_Movers_to_Puerto_Rico Movers_in_County_to_County_Flow  \
# 0                                      NaN                              25
# 1                                      NaN                               4
# 2                                      NaN                              10
# 3                                      NaN                               3
# 4                                       67                               2
#
#   Current_Residence_County_State
# 0        Autauga County, Alabama
# 1        Autauga County, Alabama
# 2        Autauga County, Alabama
# 3        Autauga County, Alabama
# 4        Autauga County, Alabama

# %%
# Add a “County and state of earlier residence” column
cleaned_cr_df['Previous_Residence_County_State'] = cleaned_cr_df['Previous_Residence_County'] +', '+ cleaned_cr_df['Previous_Residence_State/U.S._Island_Area/Foreign_Region']
cleaned_cr_df.head()
# Out:
#   Current_Residence_State Current_Residence_County  \
# 0                 Alabama           Autauga County
# 1                 Alabama           Autauga County
# 2                 Alabama           Autauga County
# 3                 Alabama           Autauga County
# 4                 Alabama           Autauga County
#
#   Current_Residence_County_Population_1_Year_and_Over  \
# 0                                              54699
# 1                                              54699
# 2                                              54699
# 3                                              54699
# 4                                              54699
#
#   Current_Residence_County_Nonmovers  \
# 0                              48066
# 1                              48066
# 2                              48066
# 3                              48066
# 4                              48066
#
#   Current_Residence_Movers_within_United_States  \
# 0                                          6539
# 1                                          6539
# 2                                          6539
# 3                                          6539
# 4                                          6539
#
#   Current_Residence_Movers_within_Same_County  \
# 0                                        2976
# 1                                        2976
# 2                                        2976
# 3                                        2976
# 4                                        2976
#
#   Current_Residence_Movers_from_Different_County_Same_State  \
# 0                                               2015
# 1                                               2015
# 2                                               2015
# 3                                               2015
# 4                                               2015
#
#   Current_Residence_Movers_from_Different_State  \
# 0                                          1548
# 1                                          1548
# 2                                          1548
# 3                                          1548
# 4                                          1548
#
#   Current_Residence_Movers_from_Abroad  \
# 0                                   94
# 1                                   94
# 2                                   94
# 3                                   94
# 4                                   94
#
#   Previous_Residence_State/U.S._Island_Area/Foreign_Region  ...  \
# 0                                            Alabama        ...
# 1                                            Alabama        ...
# 2                                            Alabama        ...
# 3                                            Alabama        ...
# 4                                            Alabama        ...
#
#   Previous_Residence_County_Population_1_Year_and_Over  \
# 0                                             207884
# 1                                              25266
# 2                                              21960
# 3                                              57849
# 4                                             113102
#
#   Previous_Residence_County_Nonmovers  \
# 0                              186155
# 1                               21406
# 2                               19860
# 3                               53424
# 4                               94947
#
#   Previous_Residence_Movers_within_United_States_or_Puerto_Rico  \
# 0                                              21729
# 1                                               3860
# 2                                               2100
# 3                                               4425
# 4                                              18088
#
#   Previous_Residence_Movers_within_Same_County  \
# 0                                        13004
# 1                                         2325
# 2                                          784
# 3                                         2024
# 4                                        11467
#
#   Previous_Residence_Movers_within_Different_County_Same_State  \
# 0                                               3133
# 1                                               1210
# 2                                               1184
# 3                                               1818
# 4                                               4162
#
#   Previous_Residence_Movers_within_Different_State  \
# 0                                             5592
# 1                                              325
# 2                                              132
# 3                                              583
# 4                                             2459
#
#   Previous_Residence_Movers_to_Puerto_Rico Movers_in_County_to_County_Flow  \
# 0                                      NaN                              25
# 1                                      NaN                               4
# 2                                      NaN                              10
# 3                                      NaN                               3
# 4                                       67                               2
#
#   Current_Residence_County_State Previous_Residence_County_State
# 0        Autauga County, Alabama         Baldwin County, Alabama
# 1        Autauga County, Alabama         Barbour County, Alabama
# 2        Autauga County, Alabama            Bibb County, Alabama
# 3        Autauga County, Alabama          Blount County, Alabama
# 4        Autauga County, Alabama         Calhoun County, Alabama
#
# [5 rows x 21 columns]

# %%
# Export to csv file
cleaned_cr_df.to_csv(".\Resources\cleaned-county-to-county-2015-2019-current-residence-sort.csv", header=True, index=False)
